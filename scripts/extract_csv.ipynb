# %%
import pandas as pd
from openai import OpenAI, APIError, RateLimitError, APIConnectionError, APITimeoutError
import logging
import time
import os
import json  # For serialization
from tqdm import tqdm
from datetime import datetime
from secret_keys import OPENAI_API_KEY  # Import your OpenAI API key from a separate file

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler("extract_csv.log"),
        logging.StreamHandler()
    ]
)

# Load your OpenAI API key
client = OpenAI(api_key=OPENAI_API_KEY)


def get_embeddings(texts, model="text-embedding-3-small", max_retries=5, backoff_factor=2):
    """
    Retrieve embeddings for a list of texts using OpenAI's Embedding API.
    
    Args:
        texts (list): A list of strings to embed.
        model (str): The embedding model to use.
        max_retries (int): Maximum number of retries for failed API calls.
        backoff_factor (int): Factor by which the wait time increases after each retry.
        
    Returns:
        list: A list of embeddings corresponding to the input texts.
    """
    for attempt in range(max_retries):
        try:
            response = client.embeddings.create(
                input=texts,
                model=model
            )
            # Extract embeddings from response using proper attribute access
            embeddings = [item.embedding for item in response.data]
            return embeddings
            
        except RateLimitError as e:
            wait = backoff_factor ** attempt
            logging.warning(f"Rate limit exceeded. Retrying in {wait} seconds... (Attempt {attempt + 1}/{max_retries})")
            logging.warning(f"Error details: {e}")
            time.sleep(wait)
            
        except APIConnectionError as e:
            wait = backoff_factor ** attempt
            logging.warning(f"Connection error. Retrying in {wait} seconds... (Attempt {attempt + 1}/{max_retries})")
            logging.warning(f"Error details: {e}")
            time.sleep(wait)
            
        except APITimeoutError as e:
            wait = backoff_factor ** attempt
            logging.warning(f"Request timeout. Retrying in {wait} seconds... (Attempt {attempt + 1}/{max_retries})")
            logging.warning(f"Error details: {e}")
            time.sleep(wait)
            
        except APIError as e:
            # This catches all other API errors (includes BadRequestError, AuthenticationError, etc.)
            logging.error(f"OpenAI API error: {e}")
            # For client errors (4xx), don't retry
            if hasattr(e, 'status_code') and 400 <= e.status_code < 500:
                logging.error("Client error - not retrying.")
                break
            # For server errors (5xx), retry
            if hasattr(e, 'status_code') and e.status_code >= 500:
                wait = backoff_factor ** attempt
                logging.warning(f"Server error. Retrying in {wait} seconds... (Attempt {attempt + 1}/{max_retries})")
                time.sleep(wait)
            else:
                break
                
        except Exception as e:
            logging.error(f"Unexpected error: {type(e).__name__}: {e}")
            break
            
    logging.error("Failed to retrieve embeddings after multiple attempts.")
    return [None] * len(texts)  # Return None embeddings for failed attempts

def add_embeddings_to_records(csv_file_path, output_file_path, batch_size=100):
    """
    Read a CSV file, generate embeddings for the 'Abstract' column where embeddings are missing, and save the results incrementally.
    
    Args:
        csv_file_path (str): Path to the input CSV file containing PubMed records.
        output_file_path (str): Path to the output CSV file to save embeddings.
        batch_size (int): Number of records to process in each batch.
    """
    # Check if output file exists
    if os.path.exists(output_file_path):
        # Resume processing from the output file
        logging.info(f"Resuming from existing output file: {output_file_path}")
        processed_ids = set()
        # Read the output file to get IDs of already processed records
        try:
            for chunk in pd.read_csv(output_file_path, usecols=['PMID'], chunksize=batch_size):
                processed_ids.update(chunk['PMID'].tolist())
        except Exception as e:
            logging.error(f"Error reading output file for processed IDs: {e}")
            return
        write_header = False  # Don't write header if appending to existing file
    else:
        processed_ids = set()
        write_header = True  # Write header if creating a new file

    # Read the input CSV file in chunks
    try:
        df_iter = pd.read_csv(csv_file_path, chunksize=batch_size)
    except FileNotFoundError:
        logging.error(f"Input file {csv_file_path} not found.")
        return
    except pd.errors.EmptyDataError:
        logging.error(f"Input file {csv_file_path} is empty.")
        return
    except Exception as e:
        logging.error(f"Error reading input file: {e}")
        return

    # Initialize progress bar
    try:
        with open(csv_file_path, 'r', encoding='utf-8') as f:
            total_records = sum(1 for _ in f) - 1  # Subtract header
    except Exception as e:
        logging.warning(f"Could not determine total records: {e}")
        total_records = None

    pbar = tqdm(total=total_records, desc="Processing Abstracts") if total_records else tqdm(desc="Processing Abstracts")

    for chunk_number, chunk in enumerate(df_iter, start=1):
        # Ensure 'Abstract' and 'PMID' columns exist
        if 'Abstract' not in chunk.columns or 'PMID' not in chunk.columns:
            logging.error("The required columns ('Abstract', 'PMID') are missing in the input file.")
            return

        # Filter out records that have already been processed
        unprocessed_chunk = chunk[~chunk['PMID'].isin(processed_ids)].copy()

        if unprocessed_chunk.empty:
            # If all records in this chunk have been processed, skip to the next chunk
            pbar.update(len(chunk))
            continue

        # Initialize 'Embedding' column if it doesn't exist
        if 'Embedding' not in unprocessed_chunk.columns:
            unprocessed_chunk['Embedding'] = None

        # Ensure 'Abstract' column is of string type
        unprocessed_chunk['Abstract'] = unprocessed_chunk['Abstract'].astype(str)

        # Handle missing or empty abstracts
        mask = unprocessed_chunk['Abstract'].notnull() & (unprocessed_chunk['Abstract'].str.strip() != "")
        abstracts = unprocessed_chunk.loc[mask, 'Abstract'].tolist()

        if abstracts:
            # Retrieve embeddings for the batch
            embeddings = get_embeddings(abstracts)

            # Check if embeddings length matches abstracts length
            if len(embeddings) != len(abstracts):
                logging.error(f"Mismatch in number of embeddings received: Expected {len(abstracts)}, Got {len(embeddings)}")
                # Assign None to all for this batch
                unprocessed_chunk.loc[mask, 'Embedding'] = None
            else:
                # Serialize each embedding as JSON string
                embeddings_serialized = [json.dumps(e) if e is not None else None for e in embeddings]
                # Assign embeddings to the corresponding rows
                unprocessed_chunk.loc[mask, 'Embedding'] = embeddings_serialized
        else:
            # If all abstracts are empty, assign None
            unprocessed_chunk['Embedding'] = None

        # Append unprocessed_chunk to the output CSV
        try:
            unprocessed_chunk.to_csv(output_file_path, mode='a', index=False, header=write_header)
            if write_header:
                write_header = False  # Header written once
        except Exception as e:
            logging.error(f"Error writing to output file: {e}")
            return

        # Update processed IDs
        processed_ids.update(unprocessed_chunk['PMID'].tolist())

        # Update progress bar
        pbar.update(len(chunk))
        logging.info(f"Processed chunk {chunk_number} with {len(unprocessed_chunk)} new records.")

    pbar.close()
    logging.info("Embedding process completed successfully.")

# Example usage
if __name__ == "__main__":
    input_csv = "../csv_results_complete.csv"              # Replace with your input CSV file path
    output_csv = "csv_results_with_embeddings.csv"      # Replace with your desired output CSV file path
    batch_size = 100                                       # Adjust based on your requirements and API limits

    # Ensure 'PMID' column exists
    if not os.path.exists(input_csv):
        logging.error(f"Input file {input_csv} not found.")
    else:
        first_chunk = pd.read_csv(input_csv, nrows=1)
        if 'PMID' not in first_chunk.columns:
            logging.error("The 'PMID' column is missing in the input file. Please ensure your input CSV contains 'PMID'.")
            exit(1)

    add_embeddings_to_records(
        csv_file_path=input_csv,
        output_file_path=output_csv,
        batch_size=batch_size
    )
# Out:
# Processing Abstracts:   0%|          | 0/3503 [00:00<?, ?it/s]2026-01-22 15:56:08,917 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Processing Abstracts:   3%|▎         | 100/3503 [00:03<01:55, 29.48it/s]2026-01-22 15:56:10,094 - INFO - Processed chunk 1 with 100 new records.
# 2026-01-22 15:56:11,889 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Processing Abstracts:   6%|▌         | 200/3503 [00:05<01:36, 34.27it/s]2026-01-22 15:56:12,680 - INFO - Processed chunk 2 with 100 new records.
# 2026-01-22 15:56:14,711 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Processing Abstracts:   9%|▊         | 300/3503 [00:09<01:37, 32.78it/s]2026-01-22 15:56:15,889 - INFO - Processed chunk 3 with 100 new records.
# 2026-01-22 15:56:18,204 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Processing Abstracts:  11%|█▏        | 400/3503 [00:12<01:40, 30.74it/s]2026-01-22 15:56:19,451 - INFO - Processed chunk 4 with 100 new records.
# 2026-01-22 15:56:21,173 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Processing Abstracts:  14%|█▍        | 500/3503 [00:15<01:34, 31.91it/s]2026-01-22 15:56:22,374 - INFO - Processed chunk 5 with 100 new records.
# 2026-01-22 15:56:24,504 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Processing Abstracts:  17%|█▋        | 600/3503 [00:18<01:32, 31.25it/s]2026-01-22 15:56:25,702 - INFO - Processed chunk 6 with 100 new records.
# 2026-01-22 15:56:27,501 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Processing Abstracts:  20%|█▉        | 700/3503 [00:22<01:30, 30.92it/s]2026-01-22 15:56:29,006 - INFO - Processed chunk 7 with 100 new records.
# 2026-01-22 15:56:31,101 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Processing Abstracts:  23%|██▎       | 800/3503 [00:25<01:30, 29.80it/s]2026-01-22 15:56:32,622 - INFO - Processed chunk 8 with 100 new records.
# 2026-01-22 15:56:34,459 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Processing Abstracts:  26%|██▌       | 900/3503 [00:28<01:24, 30.75it/s]2026-01-22 15:56:35,646 - INFO - Processed chunk 9 with 100 new records.
# 2026-01-22 15:56:38,078 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Processing Abstracts:  29%|██▊       | 1000/3503 [00:32<01:23, 29.96it/s]2026-01-22 15:56:39,175 - INFO - Processed chunk 10 with 100 new records.
# 2026-01-22 15:56:41,730 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 400 Bad Request"
# 2026-01-22 15:56:41,731 - ERROR - OpenAI API error: Error code: 400 - {'error': {'message': "This model's maximum context length is 8192 tokens, however you requested 33371 tokens (33371 in your prompt; 0 for the completion). Please reduce your prompt; or completion length.", 'type': 'invalid_request_error', 'param': None, 'code': None}}
# 2026-01-22 15:56:41,732 - ERROR - Client error - not retrying.
# 2026-01-22 15:56:41,732 - ERROR - Failed to retrieve embeddings after multiple attempts.
# Processing Abstracts:  31%|███▏      | 1100/3503 [00:35<01:14, 32.23it/s]2026-01-22 15:56:41,745 - INFO - Processed chunk 11 with 100 new records.
# 2026-01-22 15:56:43,922 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Processing Abstracts:  34%|███▍      | 1200/3503 [00:38<01:15, 30.37it/s]2026-01-22 15:56:45,473 - INFO - Processed chunk 12 with 100 new records.
# 2026-01-22 15:56:47,558 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Processing Abstracts:  37%|███▋      | 1300/3503 [00:42<01:12, 30.23it/s]2026-01-22 15:56:48,818 - INFO - Processed chunk 13 with 100 new records.
# 2026-01-22 15:56:51,173 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Processing Abstracts:  40%|███▉      | 1400/3503 [00:45<01:11, 29.50it/s]2026-01-22 15:56:52,397 - INFO - Processed chunk 14 with 100 new records.
# 2026-01-22 15:56:54,415 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Processing Abstracts:  43%|████▎     | 1500/3503 [00:48<01:06, 29.99it/s]2026-01-22 15:56:55,602 - INFO - Processed chunk 15 with 100 new records.
# 2026-01-22 15:56:56,793 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Processing Abstracts:  46%|████▌     | 1600/3503 [00:51<00:57, 32.94it/s]2026-01-22 15:56:57,944 - INFO - Processed chunk 16 with 100 new records.
# 2026-01-22 15:56:59,488 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Processing Abstracts:  49%|████▊     | 1700/3503 [00:53<00:52, 34.32it/s]2026-01-22 15:57:00,573 - INFO - Processed chunk 17 with 100 new records.
# 2026-01-22 15:57:02,074 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Processing Abstracts:  51%|█████▏    | 1800/3503 [00:56<00:49, 34.70it/s]2026-01-22 15:57:03,381 - INFO - Processed chunk 18 with 100 new records.
# 2026-01-22 15:57:04,963 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 400 Bad Request"
# 2026-01-22 15:57:04,965 - ERROR - OpenAI API error: Error code: 400 - {'error': {'message': "This model's maximum context length is 8192 tokens, however you requested 9453 tokens (9453 in your prompt; 0 for the completion). Please reduce your prompt; or completion length.", 'type': 'invalid_request_error', 'param': None, 'code': None}}
# 2026-01-22 15:57:04,965 - ERROR - Client error - not retrying.
# 2026-01-22 15:57:04,966 - ERROR - Failed to retrieve embeddings after multiple attempts.
# Processing Abstracts:  54%|█████▍    | 1900/3503 [00:58<00:40, 40.05it/s]2026-01-22 15:57:04,981 - INFO - Processed chunk 19 with 100 new records.
# 2026-01-22 15:57:06,231 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Processing Abstracts:  57%|█████▋    | 2000/3503 [01:00<00:36, 41.74it/s]2026-01-22 15:57:07,142 - INFO - Processed chunk 20 with 100 new records.
# 2026-01-22 15:57:08,853 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Processing Abstracts:  60%|█████▉    | 2100/3503 [01:03<00:34, 40.53it/s]2026-01-22 15:57:09,775 - INFO - Processed chunk 21 with 100 new records.
# 2026-01-22 15:57:10,432 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Processing Abstracts:  63%|██████▎   | 2200/3503 [01:04<00:26, 49.50it/s]2026-01-22 15:57:10,753 - INFO - Processed chunk 22 with 100 new records.
# 2026-01-22 15:57:11,998 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Processing Abstracts:  66%|██████▌   | 2300/3503 [01:06<00:26, 45.67it/s]2026-01-22 15:57:13,337 - INFO - Processed chunk 23 with 100 new records.
# 2026-01-22 15:57:14,862 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Processing Abstracts:  69%|██████▊   | 2400/3503 [01:09<00:25, 42.56it/s]2026-01-22 15:57:16,062 - INFO - Processed chunk 24 with 100 new records.
# 2026-01-22 15:57:17,763 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Processing Abstracts:  71%|███████▏  | 2500/3503 [01:12<00:25, 39.98it/s]2026-01-22 15:57:18,916 - INFO - Processed chunk 25 with 100 new records.
# 2026-01-22 15:57:20,386 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Processing Abstracts:  74%|███████▍  | 2600/3503 [01:15<00:23, 38.24it/s]2026-01-22 15:57:21,797 - INFO - Processed chunk 26 with 100 new records.
# 2026-01-22 15:57:23,017 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Processing Abstracts:  77%|███████▋  | 2700/3503 [01:17<00:20, 38.75it/s]2026-01-22 15:57:24,296 - INFO - Processed chunk 27 with 100 new records.
# 2026-01-22 15:57:25,379 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Processing Abstracts:  80%|███████▉  | 2800/3503 [01:20<00:17, 39.17it/s]2026-01-22 15:57:26,785 - INFO - Processed chunk 28 with 100 new records.
# 2026-01-22 15:57:28,101 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Processing Abstracts:  83%|████████▎ | 2900/3503 [01:21<00:13, 43.45it/s]2026-01-22 15:57:28,500 - INFO - Processed chunk 29 with 100 new records.
# 2026-01-22 15:57:30,347 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Processing Abstracts:  86%|████████▌ | 3000/3503 [01:24<00:12, 39.84it/s]2026-01-22 15:57:31,497 - INFO - Processed chunk 30 with 100 new records.
# 2026-01-22 15:57:33,092 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Processing Abstracts:  88%|████████▊ | 3100/3503 [01:27<00:10, 38.63it/s]2026-01-22 15:57:34,270 - INFO - Processed chunk 31 with 100 new records.
# 2026-01-22 15:57:35,593 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 400 Bad Request"
# 2026-01-22 15:57:35,596 - ERROR - OpenAI API error: Error code: 400 - {'error': {'message': "This model's maximum context length is 8192 tokens, however you requested 10187 tokens (10187 in your prompt; 0 for the completion). Please reduce your prompt; or completion length.", 'type': 'invalid_request_error', 'param': None, 'code': None}}
# 2026-01-22 15:57:35,597 - ERROR - Client error - not retrying.
# 2026-01-22 15:57:35,597 - ERROR - Failed to retrieve embeddings after multiple attempts.
# Processing Abstracts:  91%|█████████▏| 3200/3503 [01:28<00:06, 45.12it/s]2026-01-22 15:57:35,616 - INFO - Processed chunk 32 with 100 new records.
# 2026-01-22 15:57:37,168 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Processing Abstracts:  94%|█████████▍| 3300/3503 [01:31<00:04, 42.10it/s]2026-01-22 15:57:38,363 - INFO - Processed chunk 33 with 100 new records.
# 2026-01-22 15:57:39,441 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Processing Abstracts:  97%|█████████▋| 3400/3503 [01:34<00:02, 42.27it/s]2026-01-22 15:57:40,707 - INFO - Processed chunk 34 with 100 new records.
# 2026-01-22 15:57:42,182 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Processing Abstracts: 100%|█████████▉| 3500/3503 [01:36<00:00, 40.75it/s]2026-01-22 15:57:43,366 - INFO - Processed chunk 35 with 100 new records.
# 2026-01-22 15:57:44,194 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-01-22 15:57:44,211 - INFO - Processed chunk 36 with 3 new records.
# Processing Abstracts: 100%|██████████| 3503/3503 [01:37<00:00, 35.92it/s]
# 2026-01-22 15:57:44,212 - INFO - Embedding process completed successfully.
